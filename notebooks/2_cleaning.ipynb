# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dat = pd.read_parquet("/content/drive/MyDrive/SCCM_Datathon_Team1/data.parquet")

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360029 entries, 0 to 360028
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   patientunitstayid          360029 non-null  Int64
#  1   core_glucose_offset        360029 non-null  Int64
#  2   core_glucose               360029 non-null  float64
#  3   poc_glucose_offset         360029 non-null  Int64
#  4   poc_glucose                360029 non-null  float64
#  5   delta_offset               360029 non-null  Int64
#  6   delta_glucose              360029 non-null  float64
#  7   uniquepid                  360029 non-null  object
#  8   patienthealthsystemstayid  360029 non-null  Int64
#  9   unitvisitnumber            360029 non-null  Int64
#  10  hospitalid                 360029 non-null  Int64
#  11  region                     334291 non-null  object
#  12  unittype                   360029 non-null  object
#  13  hospitaladmitoffset        360029 non-null  Int64
#  14  hospitaldischargeoffset    360029 non-null  Int64
#  15  unitadmitoffset            360029 non-null  Int64
#  16  unitdischargeoffset        360029 non-null  Int64
#  17  apache_iv                  308075 non-null  Int64
#  18  hospitaldischargeyear      360029 non-null  Int64
#  19  age                        360029 non-null  object
#  20  hosp_mort                  355899 non-null  Int64
#  21  gender                     359975 non-null  Int64
#  22  ethnicity                  360029 non-null  object
#  23  admissionheight            357630 non-null  float64
#  24  admissionweight            348034 non-null  float64
#  25  dischargeweight            202963 non-null  float64
#  26  icu_los_hours              360029 non-null  float64
#  27  charlson_score             360029 non-null  Int64
#  28  heartrate                  209849 non-null  float64
#  29  delta_heartrate            209849 non-null  Int64
#  30  bp_mean                    196492 non-null  float64
#  31  delta_bp_mean              196492 non-null  Int64
#  32  temperature                196759 non-null  float64
#  33  delta_temperature          196759 non-null  Int64
#  34  hemoglobin                 282593 non-null  float64
#  35  delta_hemoglobin           282593 non-null  Int64
#  36  potassium                  303903 non-null  float64
#  37  delta_potassium            303903 non-null  Int64
#  38  bicarbonate                283359 non-null  float64
#  39  delta_bicarbonate          283359 non-null  Int64
#  40  bun                        302554 non-null  float64
#  41  delta_bun                  302554 non-null  Int64
#  42  creatinine                 302276 non-null  float64
#  43  delta_creatinine           302276 non-null  Int64
#  44  lactate                    38626 non-null   float64
#  45  delta_lactate              38626 non-null   Int64
#  46  insulin_past24h            360029 non-null  Int64
#  47  steroids_past24h           360029 non-null  Int64
#  48  vasopressors_past24h       360029 non-null  Int64
#  49  mech_vent_past12h          360029 non-null  Int64
# dtypes: Int64(29), float64(16), object(5)
# memory usage: 150.0+ MB

# %%
dat
# Out:
#         patientunitstayid  core_glucose_offset  core_glucose  \
# 0                  656658                 -300          45.0
# 1                  724732                 9123          43.0
# 2                 1786193                 2486          48.0
# 3                 1808587                  773         170.0
# 4                 1579198                  371          41.0
# ...                   ...                  ...           ...
# 360024             492705                 4430         154.0
# 360025             481443                   76         196.0
# 360026            1026147                -5720         186.0
# 360027            3085392                 8945         147.0
# 360028            2016353                 -250         159.0
#
#         poc_glucose_offset  poc_glucose  delta_offset  delta_glucose  \
# 0                     -334         34.0            34           11.0
# 1                     9117         36.0             6            7.0
# 2                     2528         40.0           -42            8.0
# 3                      757         40.0            16          130.0
# 4                      412         44.0           -41           -3.0
# ...                    ...          ...           ...            ...
# 360024                4426        167.0             4          -13.0
# 360025                  66        167.0            10           29.0
# 360026               -5738        167.0            18           19.0
# 360027                8932        167.0            13          -20.0
# 360028                -237        167.0           -13           -8.0
#
#          uniquepid  patienthealthsystemstayid  unitvisitnumber  ...   bun  \
# 0       006-179266                     524521                1  ...  36.0
# 1       006-144318                     565216                2  ...  27.0
# 2        018-27002                    1402676                1  ...  18.0
# 3        018-95296                    1422309                1  ...  65.0
# 4         016-2799                    1220596                1  ...   NaN
# ...            ...                        ...              ...  ...   ...
# 360024   005-13213                     417299                1  ...  15.0
# 360025   005-15450                     408073                1  ...   NaN
# 360026   008-26178                     759014                1  ...  12.0
# 360027     030-326                    2505337                1  ...  39.0
# 360028  021-249281                    1599863                1  ...  21.0
#
#        delta_bun creatinine  delta_creatinine  lactate  delta_lactate  \
# 0              0       5.02                 0      NaN           <NA>
# 1              0       5.17                 0      NaN           <NA>
# 2              0       1.16                 0      NaN           <NA>
# 3              0      12.81                 0      NaN           <NA>
# 4           <NA>       3.29                 0      NaN           <NA>
# ...          ...        ...               ...      ...            ...
# 360024         0       0.50                 0      NaN           <NA>
# 360025      <NA>        NaN              <NA>      3.6            175
# 360026         0       1.00                 0      NaN           <NA>
# 360027         0        NaN              <NA>      NaN           <NA>
# 360028         0       1.14                 0      NaN           <NA>
#
#         insulin_past24h  steroids_past24h  vasopressors_past24h  \
# 0                     0                 0                     0
# 1                     1                 0                     0
# 2                     0                 0                     0
# 3                     1                 0                     1
# 4                     0                 0                     1
# ...                 ...               ...                   ...
# 360024                0                 0                     0
# 360025                0                 0                     0
# 360026                0                 0                     0
# 360027                1                 0                     1
# 360028                0                 0                     0
#
#        mech_vent_past12h
# 0                      0
# 1                      1
# 2                      0
# 3                      1
# 4                      0
# ...                  ...
# 360024                 0
# 360025                 0
# 360026                 0
# 360027                 1
# 360028                 0
#
# [360029 rows x 50 columns]

# %%
hospital_counts = dat[['hospitalid', 'uniquepid']].groupby('hospitalid').count().reset_index()
keep_centers = hospital_counts[hospital_counts['uniquepid'] > 1000]['hospitalid']

# %%
df = dat[dat.hospitalid.isin(keep_centers)].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325402 entries, 0 to 360028
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   patientunitstayid          325402 non-null  Int64
#  1   core_glucose_offset        325402 non-null  Int64
#  2   core_glucose               325402 non-null  float64
#  3   poc_glucose_offset         325402 non-null  Int64
#  4   poc_glucose                325402 non-null  float64
#  5   delta_offset               325402 non-null  Int64
#  6   delta_glucose              325402 non-null  float64
#  7   uniquepid                  325402 non-null  object
#  8   patienthealthsystemstayid  325402 non-null  Int64
#  9   unitvisitnumber            325402 non-null  Int64
#  10  hospitalid                 325402 non-null  Int64
#  11  region                     302944 non-null  object
#  12  unittype                   325402 non-null  object
#  13  hospitaladmitoffset        325402 non-null  Int64
#  14  hospitaldischargeoffset    325402 non-null  Int64
#  15  unitadmitoffset            325402 non-null  Int64
#  16  unitdischargeoffset        325402 non-null  Int64
#  17  apache_iv                  278465 non-null  Int64
#  18  hospitaldischargeyear      325402 non-null  Int64
#  19  age                        325402 non-null  object
#  20  hosp_mort                  321732 non-null  Int64
#  21  gender                     325349 non-null  Int64
#  22  ethnicity                  325402 non-null  object
#  23  admissionheight            323467 non-null  float64
#  24  admissionweight            314929 non-null  float64
#  25  dischargeweight            183165 non-null  float64
#  26  icu_los_hours              325402 non-null  float64
#  27  charlson_score             325402 non-null  Int64
#  28  heartrate                  192279 non-null  float64
#  29  delta_heartrate            192279 non-null  Int64
#  30  bp_mean                    180338 non-null  float64
#  31  delta_bp_mean              180338 non-null  Int64
#  32  temperature                180490 non-null  float64
#  33  delta_temperature          180490 non-null  Int64
#  34  hemoglobin                 256438 non-null  float64
#  35  delta_hemoglobin           256438 non-null  Int64
#  36  potassium                  275432 non-null  float64
#  37  delta_potassium            275432 non-null  Int64
#  38  bicarbonate                255067 non-null  float64
#  39  delta_bicarbonate          255067 non-null  Int64
#  40  bun                        274098 non-null  float64
#  41  delta_bun                  274098 non-null  Int64
#  42  creatinine                 273860 non-null  float64
#  43  delta_creatinine           273860 non-null  Int64
#  44  lactate                    35672 non-null   float64
#  45  delta_lactate              35672 non-null   Int64
#  46  insulin_past24h            325402 non-null  Int64
#  47  steroids_past24h           325402 non-null  Int64
#  48  vasopressors_past24h       325402 non-null  Int64
#  49  mech_vent_past12h          325402 non-null  Int64
# dtypes: Int64(29), float64(16), object(5)
# memory usage: 135.6+ MB

# %%
# ## These cols are NA if zero, so zero fill them
# for col in ['vasopressors_past24h', 'steroids_past24h', 'insulin_past24h']:
#   df[col] = df[col].fillna(0)

for col in ['age', 'gender', 'ethnicity']:
  df.loc[df[col] == "", col] = np.nan

# Make an indicator var for age > 89 and turn age into numeric
df['age_gt_89'] = df['age'] == "> 89"
df.loc[(df['age'] == "> 89"), "age"] = "90"
df['age'] = pd.to_numeric(df['age'])

df.loc[df['admissionheight'] < 40, 'admissionheight'] = np.nan
df.loc[df['admissionheight'] > 240, 'admissionheight'] = np.nan

# %%
df.loc[df['ethnicity'].isna(), 'ethnicity'] = "Other/Unknown"

# %%
CAT_COLS = ['ethnicity', 'region', 'unittype']
for col in CAT_COLS:
  df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325402 entries, 0 to 360028
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   patientunitstayid          325402 non-null  Int64
#  1   core_glucose_offset        325402 non-null  Int64
#  2   core_glucose               325402 non-null  float64
#  3   poc_glucose_offset         325402 non-null  Int64
#  4   poc_glucose                325402 non-null  float64
#  5   delta_offset               325402 non-null  Int64
#  6   delta_glucose              325402 non-null  float64
#  7   uniquepid                  325402 non-null  object
#  8   patienthealthsystemstayid  325402 non-null  Int64
#  9   unitvisitnumber            325402 non-null  Int64
#  10  hospitalid                 325402 non-null  Int64
#  11  region                     302944 non-null  category
#  12  unittype                   325402 non-null  category
#  13  hospitaladmitoffset        325402 non-null  Int64
#  14  hospitaldischargeoffset    325402 non-null  Int64
#  15  unitadmitoffset            325402 non-null  Int64
#  16  unitdischargeoffset        325402 non-null  Int64
#  17  apache_iv                  278465 non-null  Int64
#  18  hospitaldischargeyear      325402 non-null  Int64
#  19  age                        325402 non-null  int64
#  20  hosp_mort                  321732 non-null  Int64
#  21  gender                     325349 non-null  Int64
#  22  ethnicity                  325402 non-null  category
#  23  admissionheight            323173 non-null  float64
#  24  admissionweight            314929 non-null  float64
#  25  dischargeweight            183165 non-null  float64
#  26  icu_los_hours              325402 non-null  float64
#  27  charlson_score             325402 non-null  Int64
#  28  heartrate                  192279 non-null  float64
#  29  delta_heartrate            192279 non-null  Int64
#  30  bp_mean                    180338 non-null  float64
#  31  delta_bp_mean              180338 non-null  Int64
#  32  temperature                180490 non-null  float64
#  33  delta_temperature          180490 non-null  Int64
#  34  hemoglobin                 256438 non-null  float64
#  35  delta_hemoglobin           256438 non-null  Int64
#  36  potassium                  275432 non-null  float64
#  37  delta_potassium            275432 non-null  Int64
#  38  bicarbonate                255067 non-null  float64
#  39  delta_bicarbonate          255067 non-null  Int64
#  40  bun                        274098 non-null  float64
#  41  delta_bun                  274098 non-null  Int64
#  42  creatinine                 273860 non-null  float64
#  43  delta_creatinine           273860 non-null  Int64
#  44  lactate                    35672 non-null   float64
#  45  delta_lactate              35672 non-null   Int64
#  46  insulin_past24h            325402 non-null  Int64
#  47  steroids_past24h           325402 non-null  Int64
#  48  vasopressors_past24h       325402 non-null  Int64
#  49  mech_vent_past12h          325402 non-null  Int64
#  50  age_gt_89                  325402 non-null  bool
# dtypes: Int64(29), bool(1), category(3), float64(16), int64(1), object(1)
# memory usage: 129.4+ MB

# %%
df.to_parquet("/content/drive/MyDrive/SCCM_Datathon_Team1/data_clean.parquet")

# %%
df
# Out:
#         patientunitstayid  core_glucose_offset  core_glucose  \
# 0                  656658                 -300          45.0
# 1                  724732                 9123          43.0
# 3                 1808587                  773         170.0
# 4                 1579198                  371          41.0
# 6                 2469979                 4727          96.0
# ...                   ...                  ...           ...
# 360022            3163238                 1450         208.0
# 360025             481443                   76         196.0
# 360026            1026147                -5720         186.0
# 360027            3085392                 8945         147.0
# 360028            2016353                 -250         159.0
#
#         poc_glucose_offset  poc_glucose  delta_offset  delta_glucose  \
# 0                     -334         34.0            34           11.0
# 1                     9117         36.0             6            7.0
# 3                      757         40.0            16          130.0
# 4                      412         44.0           -41           -3.0
# 6                     4762         54.0           -35           42.0
# ...                    ...          ...           ...            ...
# 360022                1454        167.0            -4           41.0
# 360025                  66        167.0            10           29.0
# 360026               -5738        167.0            18           19.0
# 360027                8932        167.0            13          -20.0
# 360028                -237        167.0           -13           -8.0
#
#          uniquepid  patienthealthsystemstayid  unitvisitnumber  ...  \
# 0       006-179266                     524521                1  ...
# 1       006-144318                     565216                2  ...
# 3        018-95296                    1422309                1  ...
# 4         016-2799                    1220596                1  ...
# 6       022-124053                    1962429                2  ...
# ...            ...                        ...              ...  ...
# 360022   032-30324                    2572279                2  ...
# 360025   005-15450                     408073                1  ...
# 360026   008-26178                     759014                1  ...
# 360027     030-326                    2505337                1  ...
# 360028  021-249281                    1599863                1  ...
#
#         delta_bun creatinine delta_creatinine  lactate  delta_lactate  \
# 0               0       5.02                0      NaN           <NA>
# 1               0       5.17                0      NaN           <NA>
# 3               0      12.81                0      NaN           <NA>
# 4            <NA>       3.29                0      NaN           <NA>
# 6               0       1.30                0      NaN           <NA>
# ...           ...        ...              ...      ...            ...
# 360022          0       1.41                0      NaN           <NA>
# 360025       <NA>        NaN             <NA>      3.6            175
# 360026          0       1.00                0      NaN           <NA>
# 360027          0        NaN             <NA>      NaN           <NA>
# 360028          0       1.14                0      NaN           <NA>
#
#         insulin_past24h  steroids_past24h  vasopressors_past24h  \
# 0                     0                 0                     0
# 1                     1                 0                     0
# 3                     1                 0                     1
# 4                     0                 0                     1
# 6                     0                 0                     0
# ...                 ...               ...                   ...
# 360022                1                 0                     0
# 360025                0                 0                     0
# 360026                0                 0                     0
# 360027                1                 0                     1
# 360028                0                 0                     0
#
#         mech_vent_past12h  age_gt_89
# 0                       0      False
# 1                       1      False
# 3                       1      False
# 4                       0      False
# 6                       0      False
# ...                   ...        ...
# 360022                  0      False
# 360025                  0      False
# 360026                  0      False
# 360027                  1      False
# 360028                  0      False
#
# [325402 rows x 51 columns]
